# %%
# retrieve Pubmed article details by either scraping a website or using a keyword or phrase
#  see https://biopython-tutorial.readthedocs.io/en/latest/notebooks/09%20-%20Accessing%20NCBIs%20Entrez%20databases.html
# (c) 2022-2023 RENCI, Chapel Hill, NC

# %%
import numpy as np
import pandas as pd
import requests
import urllib3
from Bio import Entrez
from bs4 import BeautifulSoup

Entrez.api_key = '7e2310a65401cdf4d5023cda2467c19de708'
Entrez.email = 'hubal@email.unc.edu'
Entrez.sleep_between_tries = 4 # seconds

# %%
def collect_articles_from_keyword(keyword, num_articles):
    handle = Entrez.esearch(db='pubmed', term=keyword)
    l = collect_article_details(Entrez.read(handle)['IdList'])
    if len(l) > num_articles:
        return l[0: num_articles]
    else:
        return l

def collect_articles_from_website(text):
    return collect_article_details(retrieve_pmids(text))


def collect_article_details(pmids):
    df = create_df()
    for pmid in pmids:
        a = retrieve_xml_from_pmid(pmid)
        df = append_to_df(df, [
            pmid, extract_pmcid(a), extract_title(a),
            extract_authors(a), extract_year(a), extract_journal(a),
            extract_keywords(a),
            extract_abstract(a), extract_grant(a)])
    return df

def retrieve_xml_from_url(url):
    q = requests.get(url)
    return BeautifulSoup(q.content, 'html.parser').get_text()

def retrieve_xml_from_pmid(pmid):
    return Entrez.read(Entrez.efetch(db='pubmed', id=pmid, retmode='xml'))

def retrieve_pmids(text):
    i = 1
    r = []
    while i > 0:
        i = text.find('PMID', i+1)
        t = text[i+6: i+14]
        try:
            r.append(int(t))
        except ValueError:
            r.append(-1)
    return r

def create_df():
    return pd.DataFrame({
        'PMID':[], 'PMCID':[], 'Title':[], 'Author':[], 'Year':[], 'Journal':[], 'Keywords':[], 'Abstract':[],
        'Grant':[]})

def append_to_df(df, row):
    df.loc[len(df.index)] = row
    return df

def extract_abstract(xml):
    try:
        abstract = xml['PubmedArticle'][0]['MedlineCitation']['Article']['Abstract']
        return abstract
    except IndexError:
        return None
    except KeyError:
        return None

def extract_authors(xml):
    authors = []
    try:
        for i in range (0, len(xml['PubmedArticle'][0]['MedlineCitation']['Article']['AuthorList'])):
            lname = xml['PubmedArticle'][0]['MedlineCitation']['Article']['AuthorList'][i]['LastName']
            inits = xml['PubmedArticle'][0]['MedlineCitation']['Article']['AuthorList'][i]['Initials']
            authors.append(lname + " " + inits)
        return authors
    except IndexError:
        return None
    except KeyError:
        return None

def extract_grant(xml):
    grants = []
    try:
        for i in range (0, len(xml['PubmedArticle'][0]['MedlineCitation']['Article']['GrantList'])):
            grant = xml['PubmedArticle'][0]['MedlineCitation']['Article']['GrantList'][i]['GrantID']
            agency = xml['PubmedArticle'][0]['MedlineCitation']['Article']['GrantList'][i]['Agency']
            grants.append(agency + ', ' + grant)
        return grants
    except IndexError:
        return None
    except KeyError:
        return None

def extract_journal(xml):
    try:
        journal = xml['PubmedArticle'][0]['MedlineCitation']['Article']['Journal']['Title']
        return journal
    except IndexError:
        return None
    except KeyError:
        return None

def extract_keywords(xml):
    try:
        keywords = xml['PubmedArticle'][0]['MedlineCitation']['KeywordList'][0][0]
        return keywords
    except IndexError:
        return None
    except KeyError:
        return None
    
def extract_pmcid(xml):
    try:
        pmc = xml['PubmedArticle'][0]['PubmedData']['ArticleIdList']
        j = 0
        for j in pmc:
            if j.startswith('PMC'):
                return j
    except IndexError:
        return None

def extract_title(xml):
    try:
        title = xml['PubmedArticle'][0]['MedlineCitation']['Article']['ArticleTitle']
        return title
    except IndexError:
        return None
def extract_year(xml):
    try:
        year = xml['PubmedArticle'][0]['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Year']
        return year
    except IndexError:
        return None
    except KeyError:
        return '0000'

def form_url_from_pmcid(pmcid):
    return 'http://eutils.ncbi.nlm.nih.gov/pmc/?term=(' + str(pmcid) + ')'

#def has_supplemental_data(pmcid):
    #t = retrieve_xml_from_url(form_url_from_pmcid(pmcid) + '+AND+has+suppdata%5Bfilter%5D')
    #if 'No items found' in t:
        #return False
    #else:
        #return True

# %%
# option 1: retrieve article information from scraping a website
data1 = collect_articles_from_website(retrieve_xml_from_url(
    'https://heal.nih.gov/research/publications#translation-of-research-to-practice-for-the-treatment-of-opioid-addiction'))
# Out:
# /Users/riowombacher/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# option 2: extract article information related to a given string
data2 = collect_articles_from_keyword('Hepatitus B Virus', 10)

# %%
has_suppdata=[]
for l in data1['PMCID']:
    request = requests.get("https://www.ncbi.nlm.nih.gov/pmc/?term=(" + str(l) + ")+AND+has+suppdata%5Bfilter%5D")
    soupys = BeautifulSoup(request.content, "html.parser")
    texy = soupys.get_text()
    if "No items found" in texy:
        has_suppdata.append('No')
    elif l == None:
        has_suppdata.append('No')
    else:
        has_suppdata.append('Yes')

# %%
data1['Supplemental Data'] = has_suppdata
data1['PMID']=data1['PMID'].astype(int)
clean_data = data1.drop([data1.index[191], data1.index[195]]).sort_values('Supplemental Data', ascending=False)
clean_data
# Out:
#          PMID       PMCID                                              Title  \
# 151  34213886  PMC8328003  Kratom Alkaloids as Probes for Opioid Receptor...
# 68   34174513  PMC8246150  Developmental heatmaps of brain functional con...
# 81   32592504  PMC7765737  Evaluation of human cartilage endplate composi...
# 80   33547944  PMC8697722  Measurement of vertebral endplate bone marrow ...
# 136  33631465  PMC8009840  Verifying the role of 3-hydroxy of 17-cyclopro...
# ..        ...         ...                                                ...
# 72   33386337  PMC7780957  Site-Level Variation in the Characteristics an...
# 73   33295951        None  The Healthy Brain and Child Development Study-...
# 74   35731889        None  Suvorexant ameliorated sleep disturbance, opio...
# 75   36370080        None  Biobehavioral Assessments in BACPAC: Recommend...
# 194  28564549        None  The Role of Science in Addressing the Opioid C...
#
#                                                 Author  Year  \
# 151  [Chakraborty S, Uprety R, Daibani AE, Rouzic V...  2021
# 68   [Chen H, Liu J, Chen Y, Salzwedel A, Cornea E,...  2021
# 81   [Wang L, Han M, Wong J, Zheng P, Lazar AA, Kru...  2021
# 80   [Fields AJ, Ballatori A, Han M, Bailey JF, McC...  2021
# 136  [Huang B, Gunta R, Wang H, Li M, Cao D, Mendez...  2021
# ..                                                 ...   ...
# 72                                                None  2021
# 73                   [Volkow ND, Gordon JA, Freund MP]  2021
# 74   [Huhn AS, Finan PH, Gamaldo CE, Hammond AS, Um...  2022
# 75   [Greco CM, Wasan AD, Schneider MJ, Mehling W, ...  2022
# 194                            [Volkow ND, Collins FS]  2017
#
#                                                Journal  \
# 151                          ACS chemical neuroscience
# 68                Developmental cognitive neuroscience
# 81   Journal of orthopaedic research : official pub...
# 80   European spine journal : official publication ...
# 136                               Bioorganic chemistry
# ..                                                 ...
# 72                                          Pediatrics
# 73                                     JAMA psychiatry
# 74                      Science translational medicine
# 75                       Pain medicine (Malden, Mass.)
# 194                The New England journal of medicine
#
#                    Keywords  \
# 151             Respiration
# 68                Childhood
# 81                      T2*
# 80              Bone marrow
# 136         3-Hydroxy group
# ..                      ...
# 72                     None
# 73                     None
# 74                     None
# 75   Behavioral assessments
# 194                    None
#
#                                               Abstract  \
# 151  {'AbstractText': ['Dry leaves of kratom (mitra...
# 68   {'AbstractText': ['Different functional networ...
# 81   {'AbstractText': ['Cartilage endplate (CEP) bi...
# 80   {'AbstractText': ['Vertebral endplate bone mar...
# 136  {'AbstractText': ['In the present study, the r...
# ..                                                 ...
# 72   {'AbstractText': ['Variation in pediatric medi...
# 73                                                None
# 74   {'AbstractText': ['Increased orexin/hypocretin...
# 75   {'AbstractText': ['The Biobehavioral Working G...
# 194                                               None
#
#                                                  Grant Supplemental Data
# 151  [NIDA NIH HHS, UH3 DA048379, NIDA NIH HHS, R21...               Yes
# 68   [NIDA NIH HHS, R01 DA042988, NIDA NIH HHS, R01...               Yes
# 81   [NIAMS NIH HHS, P30AR075055, NIAMS NIH HHS, UH...               Yes
# 80   [NIAMS NIH HHS, R01 AR063705, NIAMS NIH HHS, U...               Yes
# 136  [NIDA NIH HHS, P30 DA013429, NIDA NIH HHS, R01...               Yes
# ..                                                 ...               ...
# 72   [NICHD NIH HHS, UG1 HD027853, NIH HHS, UG1 OD0...                No
# 73                                                None                No
# 74                        [NIDA NIH HHS, UG3 DA048734]                No
# 75                                                None                No
# 194                                               None                No
#
# [194 rows x 10 columns]

# %%
datay = data1[data1['Grant'].isnull()]
datay
# Out:
#          PMID       PMCID                                              Title  \
# 5    34598100  PMC8397502  The impact of the national stay-at-home order ...
# 24   33487517        None  Justice community opioid innovation network (J...
# 25   34495340  PMC8427378  Comparison of Treatment Retention of Adults Wi...
# 44   34139948        None  Examining the Relationship between Social Conn...
# 46   34080556  PMC8028689  Impact of COVID-19 on service delivery for an ...
# 70   33386340        None  It Is Time to ACT NOW to Improve Quality for O...
# 71   33433576  PMC7804920  Neonatal Abstinence Syndrome and Maternal Opio...
# 73   33295951        None  The Healthy Brain and Child Development Study-...
# 75   36370080        None  Biobehavioral Assessments in BACPAC: Recommend...
# 76   36315069        None  Deep Learning for Multi-Tissue Segmentation an...
# 77   36315101        None  Biomechanical Phenotyping of Chronic Low Back ...
# 98   31697052        None  An Injectable Neural Stimulation Electrode Mad...
# 102  35125139        None  Deep Brain Stimulation of the Subgenual Cingul...
# 111  34752775  PMC8776619  Synchronized cluster firing, a distinct form o...
# 116  33478555  PMC7819318  Non-SUMOylated CRMP2 decreases Na<sub>V</sub>1...
# 145  34043402  PMC8422285  Deep brain stimulation of the nucleus accumben...
# 156  34454912  PMC8388132  Covid-19 interface with drug misuse and substa...
# 169  35119273  PMC9176367  Thieno[2,3-<i>d</i>]pyrimidine-Based Positive ...
# 172  34861164  PMC8693769  Robotic high-throughput biomanufacturing and f...
# 180  34832729  PMC8621475  Investigating the Function of Adult DRG Neuron...
# 188  34447323  PMC8382852  An Effective and Safe Novel Treatment of Opioi...
# 191  23762962         NaN                                                NaN
# 193  29896636  PMC6688196  Helping to End Addiction Over the Long-term: T...
# 194  28564549        None  The Role of Science in Addressing the Opioid C...
#
#                                                 Author  Year  \
# 5    [Root ED, Slavova S, LaRochelle M, Feaster DJ,...  2021
# 24   [Knight D, Becan J, Olson D, Davis NP, Jones J...  2021
# 25   [Lee JD, Malone M, McDonald R, Cheng A, Vasude...  2021
# 44   [Cance JD, Saavedra LM, Wondimu B, Scaglione N...  2021
# 46                   [Cruden G, Campbell M, Saldana L]  2021
# 70                              [Patrick SW, Lorch SA]  2021
# 71   [Hirai AH, Ko JY, Owens PL, Stocks C, Patrick SW]  2021
# 73                   [Volkow ND, Gordon JA, Freund MP]  2021
# 75   [Greco CM, Wasan AD, Schneider MJ, Mehling W, ...  2022
# 76   [Hess M, Allaire B, Gao KT, Tibrewala R, Inamd...  2022
# 77   [Adam Quirk D, Johnson ME, Anderson DE, Smuck ...  2022
# 98   [Trevathan JK, Baumgart IW, Nicolai EN, Gosink...  2019
# 102     [Kashanian A, Tsolaki E, Pouratian N, Bari AA]  2022
# 111  [Zheng Q, Xie W, Lückemeyer DD, Lay M, Wang XW...  2022
# 116    [Gomez K, Ran D, Madura CL, Moutal A, Khanna R]  2021
# 145  [Mahoney JJ, Haut MW, Hodder SL, Zheng W, Land...  2021
# 156                       [Cisneros IE, Cunningham KA]  2021
# 169  [Berhane I, Hin N, Thomas AG, Huang Q, Zhang C...  2022
# 172  [Tristan CA, Ormanoglu P, Slamecka J, Malley C...  2021
# 180  [Atmaramani R, Veeramachaneni S, Mogas LV, Kop...  2021
# 188  [Schiffer F, Khan A, Bolger E, Flynn E, Seltze...  2021
# 191                                                NaN   NaN
# 193              [Collins FS, Koroshetz WJ, Volkow ND]  2018
# 194                            [Volkow ND, Collins FS]  2017
#
#                                                Journal  \
# 5                          Drug and alcohol dependence
# 24                Journal of substance abuse treatment
# 25                                   JAMA network open
# 44                              Substance use & misuse
# 46                Journal of substance abuse treatment
# 70                                          Pediatrics
# 71                                                JAMA
# 73                                     JAMA psychiatry
# 75                       Pain medicine (Malden, Mass.)
# 76                       Pain medicine (Malden, Mass.)
# 77                       Pain medicine (Malden, Mass.)
# 98                       Advanced healthcare materials
# 102  Neuromodulation : journal of the International...
# 111                                             Neuron
# 116                                    Molecular brain
# 145       Experimental and clinical psychopharmacology
# 156                                  Neuropharmacology
# 169                     Journal of medicinal chemistry
# 172                                  Stem cell reports
# 180                                      Micromachines
# 188                            Frontiers in psychiatry
# 191                                                NaN
# 193                                               JAMA
# 194                The New England journal of medicine
#
#                    Keywords  \
# 5                  COVID-19
# 24   Implementation science
# 25                     None
# 44                  Opioids
# 46                 COVID-19
# 70                     None
# 71                     None
# 73                     None
# 75   Behavioral assessments
# 76                   BACPAC
# 77             Biomechanics
# 98             biomaterials
# 102   Chronic low back pain
# 111                     DRG
# 116                   CRMP2
# 145                    None
# 156  Central nervous system
# 169                    None
# 172           CEPT cocktail
# 180      axonal stimulation
# 188  hemispheric laterality
# 191                     NaN
# 193                    None
# 194                    None
#
#                                               Abstract Grant Supplemental Data
# 5    {'AbstractText': ['Although national syndromic...  None               Yes
# 24   {'AbstractText': ['Recognizing the current opi...  None                No
# 25   {'AbstractText': ['Extended-release buprenorph...  None               Yes
# 44   {'AbstractText': ['We used a Boolean search st...  None                No
# 46   {'AbstractText': ['The novel coronavirus, COVI...  None                No
# 70                                                None  None                No
# 71   {'AbstractText': ['Substantial increases in bo...  None               Yes
# 73                                                None  None                No
# 75   {'AbstractText': ['The Biobehavioral Working G...  None                No
# 76   {'AbstractText': ['In vivo retrospective study...  None                No
# 77   {'AbstractText': ['Biomechanics represents the...  None                No
# 98   {'AbstractText': ['Implanted neural stimulatio...  None                No
# 102  {'AbstractText': ['Despite converging basic sc...  None                No
# 111  {'AbstractText': ['Spontaneous pain refers to ...  None               Yes
# 116  {'AbstractText': ['Voltage-gated sodium channe...  None               Yes
# 145  {'AbstractText': ['Given high relapse rates an...  None               Yes
# 156  {'AbstractText': ['The coronavirus disease 201...  None                No
# 169  {'AbstractText': ['Mas-related G protein-coupl...  None               Yes
# 172  {'AbstractText': ['Efficient translation of hu...  None               Yes
# 180  {'AbstractText': ['A critical role of the peri...  None                No
# 188  {'AbstractText': ['<b>Background:</b> The opio...  None               Yes
# 191                                                NaN   NaN               Yes
# 193                                               None  None                No
# 194                                               None  None                No

# %%
#Post to github when I put in error codes for -1 and no info at all
#sort by supplemental data Yes on top and then PMID from there
